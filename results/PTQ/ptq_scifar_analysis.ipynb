# %%
from glob import glob 
import os
import pandas as pd

# %%
folder = "/home/sabreu/NeuroSSMs/results/PTQ"
task = "scifar"
csv_file = os.path.join(folder, f"raw_data_{task}.csv")

if not os.path.exists(csv_file):
    dfs = []
    for fname in glob(f"{folder}/*.txt"):
        df = pd.read_csv(f"{fname}")
        x = fname.split("/")[-1].strip('.txt').replace(f'ptq_results_eval-ptq--{task}-full-', '')
        x = x.replace('lnrm', 'LN').replace('ln_nb', 'LN*').replace("--", " ").replace("fp", "Baseline")
        df.index = [x]
        dfs.append(df)
    df = pd.concat(dfs).sort_index()
    df.to_csv(csv_file)
else:
    df = pd.read_csv(csv_file, index_col=0)

df["name"] = df.index
df["0qgelu"] = df["name"].apply(lambda x: "\\checkmark" if "qgelu" in x else "")
df["0hsigmoid"] = df["name"].apply(lambda x: "\\checkmark" if "hsigmoid" in x else "")
df["0qln"] = df["name"].apply(lambda x: "\\checkmark" if "qln" in x else "")
df = df.sort_index(axis=1)
df.columns = [e.replace("0", "") for e in df.columns]
df.index = [e.split(" ")[1].split("-")[0] + " " + e.split(" ")[0] for e in df.index]

df_ = df[['qgelu', 'hsigmoid', 'qln', 'test_acc']]
for c in df_.columns:
    if 'acc' in c:
        df_.loc[:,c] = df_[c].apply(lambda x: f"{x:.2%}")
print(df_.to_latex().replace("%", "\\%"))
df
# Out:
# \begin{tabular}{lllll}
# \toprule
#  & qgelu & hsigmoid & qln & test_acc \\
# \midrule
# scifar ptq_results_eval-ptq &  &  &  & 85.46\% \\
# scifar ptq_results_eval-ptq &  & \checkmark &  & 43.65\% \\
# scifar ptq_results_eval-ptq &  &  &  & 43.33\% \\
# scifar ptq_results_eval-ptq &  &  & \checkmark & 43.50\% \\
# scifar ptq_results_eval-ptq & \checkmark & \checkmark & \checkmark & 44.83\% \\
# scifar ptq_results_eval-ptq & \checkmark &  &  & 45.11\% \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_414662/1395729975.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['85.46%' '43.65%' '43.33%' '43.50%' '44.83%' '45.11%']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_.loc[:,c] = df_[c].apply(lambda x: f"{x:.2%}")
#                                hsigmoid       qgelu         qln  \
# scifar ptq_results_eval-ptq
# scifar ptq_results_eval-ptq  \checkmark
# scifar ptq_results_eval-ptq
# scifar ptq_results_eval-ptq                          \checkmark
# scifar ptq_results_eval-ptq  \checkmark  \checkmark  \checkmark
# scifar ptq_results_eval-ptq              \checkmark
#
#                                                                           name  \
# scifar ptq_results_eval-ptq      ptq_results_eval-ptq scifar-full-LN* Baseline
# scifar ptq_results_eval-ptq  ptq_results_eval-ptq scifar-full-LN* W8A8-gelu...
# scifar ptq_results_eval-ptq  ptq_results_eval-ptq scifar-full-LN* W8A8-gelu...
# scifar ptq_results_eval-ptq  ptq_results_eval-ptq scifar-full-LN* W8A8-gelu...
# scifar ptq_results_eval-ptq  ptq_results_eval-ptq scifar-full-LN* W8A8-qgel...
# scifar ptq_results_eval-ptq  ptq_results_eval-ptq scifar-full-LN* W8A8-qgel...
#
#                              test_acc  test_loss  train_acc  train_loss  \
# scifar ptq_results_eval-ptq    0.8546   0.820483   1.000000    0.000006
# scifar ptq_results_eval-ptq    0.4365   2.893650   0.480667    2.449910
# scifar ptq_results_eval-ptq    0.4333   2.933707   0.480933    2.477166
# scifar ptq_results_eval-ptq    0.4350   2.923786   0.480667    2.478014
# scifar ptq_results_eval-ptq    0.4483   2.726842   0.494089    2.289321
# scifar ptq_results_eval-ptq    0.4511   2.731855   0.496044    2.283669
#
#                              val_acc  val_loss
# scifar ptq_results_eval-ptq   0.8654  0.769089
# scifar ptq_results_eval-ptq   0.4336  2.886853
# scifar ptq_results_eval-ptq   0.4308  2.906049
# scifar ptq_results_eval-ptq   0.4302  2.916495
# scifar ptq_results_eval-ptq   0.4370  2.738611
# scifar ptq_results_eval-ptq   0.4406  2.728443
